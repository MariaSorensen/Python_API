# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
response_json = [];
url = "http://api.openweathermap.org/data/2.5/weather?q="
print(f"Beginning Data Retrieval")
print(f"---------------------------")

# Make a request for each of the indices
for x in range(len(cities)):
    print(f"Processing Record {x} | {cities[x]}")

    # Get one of the posts
    post_response = requests.get(url + cities[x] + "&APPID=" + api_key)

    # Save post's JSON
    response_json.append(post_response.json())
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 0 | zaysan
# Processing Record 1 | wattegama
# Processing Record 2 | veraval
# Processing Record 3 | hithadhoo
# Processing Record 4 | ahmadnagar
# Processing Record 5 | nikolskoye
# Processing Record 6 | jamestown
# Processing Record 7 | ribeira grande
# Processing Record 8 | port elizabeth
# Processing Record 9 | yulara
# Processing Record 10 | opuwo
# Processing Record 11 | kodiak
# Processing Record 12 | sao joao da barra
# Processing Record 13 | chicama
# Processing Record 14 | somerset east
# Processing Record 15 | hobart
# Processing Record 16 | lebu
# Processing Record 17 | ahipara
# Processing Record 18 | atuona
# Processing Record 19 | albany
# Processing Record 20 | rzhev
# Processing Record 21 | tuktoyaktuk
# Processing Record 22 | paracuru
# Processing Record 23 | mar del plata
# Processing Record 24 | carnarvon
# Processing Record 25 | punta arenas
# Processing Record 26 | nampula
# Processing Record 27 | ushuaia
# Processing Record 28 | barentsburg
# Processing Record 29 | patacamaya
# Processing Record 30 | upernavik
# Processing Record 31 | saint anthony
# Processing Record 32 | mataura
# Processing Record 33 | rikitea
# Processing Record 34 | victoria
# Processing Record 35 | salalah
# Processing Record 36 | alampur
# Processing Record 37 | minna
# Processing Record 38 | mont-de-marsan
# Processing Record 39 | nanortalik
# Processing Record 40 | bonavista
# Processing Record 41 | port alfred
# Processing Record 42 | qandala
# Processing Record 43 | chokurdakh
# Processing Record 44 | ostrovnoy
# Processing Record 45 | ancud
# Processing Record 46 | faanui
# Processing Record 47 | cururupu
# Processing Record 48 | nantucket
# Processing Record 49 | isla aguada
# Processing Record 50 | mrirt
# Processing Record 51 | kumluca
# Processing Record 52 | deputatskiy
# Processing Record 53 | coffs harbour
# Processing Record 54 | wajima
# Processing Record 55 | dingle
# Processing Record 56 | barrow
# Processing Record 57 | taolanaro
# Processing Record 58 | kieta
# Processing Record 59 | nuuk
# Processing Record 60 | san quintin
# Processing Record 61 | makakilo city
# Processing Record 62 | port hedland
# Processing Record 63 | nioro
# Processing Record 64 | bethel
# Processing Record 65 | arona
# Processing Record 66 | sao felix do xingu
# Processing Record 67 | bluff
# Processing Record 68 | awbari
# Processing Record 69 | rocha
# Processing Record 70 | te anau
# Processing Record 71 | acapulco
# Processing Record 72 | esperance
# Processing Record 73 | sompeta
# Processing Record 74 | khatanga
# Processing Record 75 | otradnoye
# Processing Record 76 | bengkulu
# Processing Record 77 | katsuura
# Processing Record 78 | cabo san lucas
# Processing Record 79 | odienne
# Processing Record 80 | lasa
# Processing Record 81 | zhigansk
# Processing Record 82 | bacolod
# Processing Record 83 | dali
# Processing Record 84 | bozeman
# Processing Record 85 | rayachoti
# Processing Record 86 | dakar
# Processing Record 87 | puerto ayora
# Processing Record 88 | qui nhon
# Processing Record 89 | vaini
# Processing Record 90 | tubruq
# Processing Record 91 | busselton
# Processing Record 92 | varhaug
# Processing Record 93 | xiaoweizhai
# Processing Record 94 | tasiilaq
# Processing Record 95 | hambantota
# Processing Record 96 | liverpool
# Processing Record 97 | grindavik
# Processing Record 98 | lagoa
# Processing Record 99 | takoradi
# Processing Record 100 | mayya
# Processing Record 101 | porto novo
# Processing Record 102 | ilulissat
# Processing Record 103 | butaritari
# Processing Record 104 | gat
# Processing Record 105 | nara
# Processing Record 106 | new norfolk
# Processing Record 107 | belushya guba
# Processing Record 108 | hilo
# Processing Record 109 | charagua
# Processing Record 110 | grand river south east
# Processing Record 111 | lamesa
# Processing Record 112 | port macquarie
# Processing Record 113 | ligayan
# Processing Record 114 | beloha
# Processing Record 115 | telma
# Processing Record 116 | mujiayingzi
# Processing Record 117 | urrao
# Processing Record 118 | codrington
# Processing Record 119 | vao
# Processing Record 120 | velsk
# Processing Record 121 | manta
# Processing Record 122 | half moon bay
# Processing Record 123 | san ramon
# Processing Record 124 | nizhneyansk
# Processing Record 125 | hermanus
# Processing Record 126 | jining
# Processing Record 127 | calnali
# Processing Record 128 | booue
# Processing Record 129 | san policarpo
# Processing Record 130 | kaeo
# Processing Record 131 | makat
# Processing Record 132 | thompson
# Processing Record 133 | avarua
# Processing Record 134 | labutta
# Processing Record 135 | castro
# Processing Record 136 | kungurtug
# Processing Record 137 | rexburg
# Processing Record 138 | atka
# Processing Record 139 | kahului
# Processing Record 140 | geraldton
# Processing Record 141 | cape town
# Processing Record 142 | isla vista
# Processing Record 143 | kaitangata
# Processing Record 144 | bollnas
# Processing Record 145 | saint-joseph
# Processing Record 146 | tilichiki
# Processing Record 147 | san cristobal
# Processing Record 148 | bandarbeyla
# Processing Record 149 | westport
# Processing Record 150 | ugoofaaru
# Processing Record 151 | longyearbyen
# Processing Record 152 | atasu
# Processing Record 153 | lolua
# Processing Record 154 | leningradskiy
# Processing Record 155 | pisco
# Processing Record 156 | yerbogachen
# Processing Record 157 | mathathane
# Processing Record 158 | samusu
# Processing Record 159 | east london
# Processing Record 160 | baruun-urt
# Processing Record 161 | dubenskiy
# Processing Record 162 | illoqqortoormiut
# Processing Record 163 | port hardy
# Processing Record 164 | nacala
# Processing Record 165 | torit
# Processing Record 166 | zenzeli
# Processing Record 167 | tiksi
# Processing Record 168 | yellowknife
# Processing Record 169 | tuatapere
# Processing Record 170 | kunnamangalam
# Processing Record 171 | codigoro
# Processing Record 172 | pasighat
# Processing Record 173 | buarcos
# Processing Record 174 | manzil tamim
# Processing Record 175 | medicine hat
# Processing Record 176 | saskylakh
# Processing Record 177 | georgetown
# Processing Record 178 | viligili
# Processing Record 179 | les escoumins
# Processing Record 180 | pevek
# Processing Record 181 | clyde river
# Processing Record 182 | hamilton
# Processing Record 183 | saleaula
# Processing Record 184 | warqla
# Processing Record 185 | pingliang
# Processing Record 186 | vestmannaeyjar
# Processing Record 187 | souillac
# Processing Record 188 | coshocton
# Processing Record 189 | vila franca do campo
# Processing Record 190 | buraydah
# Processing Record 191 | non thai
# Processing Record 192 | innisfail
# Processing Record 193 | selty
# Processing Record 194 | pinsk
# Processing Record 195 | ha tinh
# Processing Record 196 | tarboro
# Processing Record 197 | tortoli
# Processing Record 198 | karaul
# Processing Record 199 | dolbeau
# Processing Record 200 | rocky mountain house
# Processing Record 201 | bredasdorp
# Processing Record 202 | sumbe
# Processing Record 203 | airai
# Processing Record 204 | iqaluit
# Processing Record 205 | kangaatsiaq
# Processing Record 206 | byron bay
# Processing Record 207 | klaksvik
# Processing Record 208 | aklavik
# Processing Record 209 | alofi
# Processing Record 210 | xuddur
# Processing Record 211 | comodoro rivadavia
# Processing Record 212 | constantine
# Processing Record 213 | puerto escondido
# Processing Record 214 | dikson
# Processing Record 215 | norman wells
# Processing Record 216 | arman
# Processing Record 217 | diu
# Processing Record 218 | quelimane
# Processing Record 219 | bur gabo
# Processing Record 220 | hasaki
# Processing Record 221 | kawalu
# Processing Record 222 | beira
# Processing Record 223 | namatanai
# Processing Record 224 | provideniya
# Processing Record 225 | praia da vitoria
# Processing Record 226 | lorengau
# Processing Record 227 | longlac
# Processing Record 228 | abu zabad
# Processing Record 229 | hofn
# Processing Record 230 | inyonga
# Processing Record 231 | kiruna
# Processing Record 232 | amderma
# Processing Record 233 | hegra
# Processing Record 234 | portland
# Processing Record 235 | taksimo
# Processing Record 236 | guaratinga
# Processing Record 237 | wad rawah
# Processing Record 238 | roald
# Processing Record 239 | gunnedah
# Processing Record 240 | karaton
# Processing Record 241 | besikduzu
# Processing Record 242 | namibe
# Processing Record 243 | ankang
# Processing Record 244 | chuy
# Processing Record 245 | tezu
# Processing Record 246 | yar-sale
# Processing Record 247 | sakakah
# Processing Record 248 | moche
# Processing Record 249 | bereda
# Processing Record 250 | nizhniy baskunchak
# Processing Record 251 | cherskiy
# Processing Record 252 | babstovo
# Processing Record 253 | fougamou
# Processing Record 254 | wanning
# Processing Record 255 | tabas
# Processing Record 256 | wadena
# Processing Record 257 | paharpur
# Processing Record 258 | shenzhen
# Processing Record 259 | berlevag
# Processing Record 260 | omboue
# Processing Record 261 | luderitz
# Processing Record 262 | balimo
# Processing Record 263 | bambous virieux
# Processing Record 264 | torbay
# Processing Record 265 | mahebourg
# Processing Record 266 | moranbah
# Processing Record 267 | naze
# Processing Record 268 | sitka
# Processing Record 269 | olden
# Processing Record 270 | cabedelo
# Processing Record 271 | xuanzhou
# Processing Record 272 | port blair
# Processing Record 273 | usinsk
# Processing Record 274 | diamantino
# Processing Record 275 | lazaro cardenas
# Processing Record 276 | baloda
# Processing Record 277 | necochea
# Processing Record 278 | avera
# Processing Record 279 | black river
# Processing Record 280 | komsomolskiy
# Processing Record 281 | naryan-mar
# Processing Record 282 | urumqi
# Processing Record 283 | bathsheba
# Processing Record 284 | vanimo
# Processing Record 285 | palencia
# Processing Record 286 | barntrup
# Processing Record 287 | iguape
# Processing Record 288 | mersing
# Processing Record 289 | wairoa
# Processing Record 290 | saldanha
# Processing Record 291 | kapaa
# Processing Record 292 | la rioja
# Processing Record 293 | petrolina
# Processing Record 294 | leh
# Processing Record 295 | mackenzie
# Processing Record 296 | qianan
# Processing Record 297 | narathiwat
# Processing Record 298 | graaff-reinet
# Processing Record 299 | marcona
# Processing Record 300 | vaitupu
# Processing Record 301 | emerald
# Processing Record 302 | qaanaaq
# Processing Record 303 | kruisfontein
# Processing Record 304 | cidreira
# Processing Record 305 | maues
# Processing Record 306 | chumikan
# Processing Record 307 | thongwa
# Processing Record 308 | tabora
# Processing Record 309 | palmar
# Processing Record 310 | torrevieja
# Processing Record 311 | ponta delgada
# Processing Record 312 | kysyl-syr
# Processing Record 313 | sug-aksy
# Processing Record 314 | saint-philippe
# Processing Record 315 | amahai
# Processing Record 316 | poronaysk
# Processing Record 317 | ewa beach
# Processing Record 318 | guadalupe y calvo
# Processing Record 319 | rawson
# Processing Record 320 | pouebo
# Processing Record 321 | gobabis
# Processing Record 322 | thinadhoo
# Processing Record 323 | lompoc
# Processing Record 324 | haimen
# Processing Record 325 | asau
# Processing Record 326 | padang
# Processing Record 327 | chiang klang
# Processing Record 328 | mullaitivu
# Processing Record 329 | mys shmidta
# Processing Record 330 | okakarara
# Processing Record 331 | cowra
# Processing Record 332 | manbij
# Processing Record 333 | manoel urbano
# Processing Record 334 | delta
# Processing Record 335 | rancharia
# Processing Record 336 | greensboro
# Processing Record 337 | kadipaten
# Processing Record 338 | yatou
# Processing Record 339 | mkushi
# Processing Record 340 | bagahanglad
# Processing Record 341 | price
# Processing Record 342 | adrar
# Processing Record 343 | margate
# Processing Record 344 | luganville
# Processing Record 345 | deh rawud
# Processing Record 346 | narsaq
# Processing Record 347 | ambulu
# Processing Record 348 | buala
# Processing Record 349 | kissidougou
# Processing Record 350 | muisne
# Processing Record 351 | allapalli
# Processing Record 352 | roseto degli abruzzi
# Processing Record 353 | guajara-mirim
# Processing Record 354 | kintampo
# Processing Record 355 | williams lake
# Processing Record 356 | wahpeton
# Processing Record 357 | lavrentiya
# Processing Record 358 | mayor pablo lagerenza
# Processing Record 359 | saint george
# Processing Record 360 | kisber
# Processing Record 361 | severo-kurilsk
# Processing Record 362 | valmiera
# Processing Record 363 | dudinka
# Processing Record 364 | mahibadhoo
# Processing Record 365 | eyl
# Processing Record 366 | sao miguel do oeste
# Processing Record 367 | manono
# Processing Record 368 | gravelbourg
# Processing Record 369 | folkestone
# Processing Record 370 | miyako
# Processing Record 371 | dwarka
# Processing Record 372 | riosucio
# Processing Record 373 | meulaboh
# Processing Record 374 | kavieng
# Processing Record 375 | eislingen
# Processing Record 376 | atbasar
# Processing Record 377 | nanakuli
# Processing Record 378 | richmond
# Processing Record 379 | alice springs
# Processing Record 380 | plettenberg bay
# Processing Record 381 | uttaradit
# Processing Record 382 | faya
# Processing Record 383 | kargasok
# Processing Record 384 | constitucion
# Processing Record 385 | jiddah
# Processing Record 386 | kamien pomorski
# Processing Record 387 | patiya
# Processing Record 388 | vardo
# Processing Record 389 | ponta do sol
# Processing Record 390 | lata
# Processing Record 391 | ulenje
# Processing Record 392 | brae
# Processing Record 393 | vostok
# Processing Record 394 | fairbanks
# Processing Record 395 | petropavlovsk-kamchatskiy
# Processing Record 396 | nianzishan
# Processing Record 397 | sechura
# Processing Record 398 | kloulklubed
# Processing Record 399 | coihaique
# Processing Record 400 | muzhi
# Processing Record 401 | moron
# Processing Record 402 | tumannyy
# Processing Record 403 | buchanan
# Processing Record 404 | leninskoye
# Processing Record 405 | kamachumu
# Processing Record 406 | moree
# Processing Record 407 | ryotsu
# Processing Record 408 | manzanillo
# Processing Record 409 | kharp
# Processing Record 410 | le vauclin
# Processing Record 411 | eganville
# Processing Record 412 | gidam
# Processing Record 413 | pokoynoye
# Processing Record 414 | okhotsk
# Processing Record 415 | chara
# Processing Record 416 | shetpe
# Processing Record 417 | fortuna
# Processing Record 418 | beringovskiy
# Processing Record 419 | road town
# Processing Record 420 | goldsboro
# Processing Record 421 | halalo
# Processing Record 422 | kasongo-lunda
# Processing Record 423 | turukhansk
# Processing Record 424 | touros
# Processing Record 425 | sladkovo
# Processing Record 426 | dunedin
# Processing Record 427 | toftir
# Processing Record 428 | kongolo
# Processing Record 429 | fare
# Processing Record 430 | izhma
# Processing Record 431 | tsihombe
# Processing Record 432 | warmbad
# Processing Record 433 | newark
# Processing Record 434 | agadir
# Processing Record 435 | kununurra
# Processing Record 436 | tadine
# Processing Record 437 | nome
# Processing Record 438 | mnogovershinnyy
# Processing Record 439 | kjellerup
# Processing Record 440 | sao paulo do potengi
# Processing Record 441 | kutum
# Processing Record 442 | kitami
# Processing Record 443 | puerto baquerizo moreno
# Processing Record 444 | talnakh
# Processing Record 445 | guerrero negro
# Processing Record 446 | hunza
# Processing Record 447 | zhezkazgan
# Processing Record 448 | zhenhai
# Processing Record 449 | mega
# Processing Record 450 | duzce
# Processing Record 451 | itaocara
# Processing Record 452 | foz
# Processing Record 453 | keffi
# Processing Record 454 | polaniec
# Processing Record 455 | palampur
# Processing Record 456 | sao filipe
# Processing Record 457 | hami
# Processing Record 458 | kankan
# Processing Record 459 | frederico westphalen
# Processing Record 460 | sohag
# Processing Record 461 | ulladulla
# Processing Record 462 | winston-salem
# Processing Record 463 | anandnagar
# Processing Record 464 | el alto
# Processing Record 465 | olafsvik
# Processing Record 466 | yanam
# Processing Record 467 | visnes
# Processing Record 468 | atambua
# Processing Record 469 | uchaly
# Processing Record 470 | kostomuksha
# Processing Record 471 | kurchanskaya
# Processing Record 472 | wanderlandia
# Processing Record 473 | chagda
# Processing Record 474 | wana
# Processing Record 475 | hajdunanas
# Processing Record 476 | pauini
# Processing Record 477 | kitimat
# Processing Record 478 | kavaratti
# Processing Record 479 | tiarei
# Processing Record 480 | nishihara
# Processing Record 481 | kropotkin
# Processing Record 482 | saint joseph
# Processing Record 483 | lethem
# Processing Record 484 | ketchikan
# Processing Record 485 | jumla
# Processing Record 486 | kaputa
# Processing Record 487 | husavik
# Processing Record 488 | esna
# Processing Record 489 | fukuma
# Processing Record 490 | aykhal
# Processing Record 491 | jardim
# Processing Record 492 | bogo
# Processing Record 493 | mitsamiouli
# Processing Record 494 | solnechnyy
# Processing Record 495 | mananara
# Processing Record 496 | toliary
# Processing Record 497 | kosh-agach
# Processing Record 498 | xai-xai
# Processing Record 499 | moerai
# Processing Record 500 | sentyabrskiy
# Processing Record 501 | louisbourg
# Processing Record 502 | sidi ali
# Processing Record 503 | sinnamary
# Processing Record 504 | kerema
# Processing Record 505 | chandbali
# Processing Record 506 | arraial do cabo
# Processing Record 507 | katangli
# Processing Record 508 | blackwater
# Processing Record 509 | martapura
# Processing Record 510 | sapucaia
# Processing Record 511 | aasiaat
# Processing Record 512 | taoudenni
# Processing Record 513 | clonakilty
# Processing Record 514 | crab hill
# Processing Record 515 | maniitsoq
# Processing Record 516 | burgersdorp
# Processing Record 517 | de-kastri
# Processing Record 518 | qena
# Processing Record 519 | mogadishu
# Processing Record 520 | rafiganj
# Processing Record 521 | hovd
# Processing Record 522 | shelburne
# Processing Record 523 | ndele
# Processing Record 524 | phonhong
# Processing Record 525 | nizhniy odes
# Processing Record 526 | riyadh
# Processing Record 527 | scarborough
# Processing Record 528 | douglasville
# Processing Record 529 | aviles
# Processing Record 530 | rio cuarto
# Processing Record 531 | korla
# Processing Record 532 | mayo
# Processing Record 533 | krasnoselkup
# Processing Record 534 | nago
# Processing Record 535 | tomatlan
# Processing Record 536 | havelock
# Processing Record 537 | ballina
# Processing Record 538 | saint-louis
# Processing Record 539 | eisenberg
# Processing Record 540 | caravelas
# Processing Record 541 | fevralsk
# Processing Record 542 | paysandu
# Processing Record 543 | manaure
# Processing Record 544 | telimele
# Processing Record 545 | dingli
# Processing Record 546 | nyandoma
# Processing Record 547 | ahuimanu
# Processing Record 548 | seoul
# Processing Record 549 | sao gabriel da cachoeira
# Processing Record 550 | tumut
# Processing Record 551 | ngukurr
# Processing Record 552 | iralaya
# Processing Record 553 | kuliyapitiya
# Processing Record 554 | waddan
# Processing Record 555 | dalby
# Processing Record 556 | battle creek
# Processing Record 557 | athabasca
# Processing Record 558 | almaznyy
# Processing Record 559 | rafai
# Processing Record 560 | tura
# Processing Record 561 | pacific grove
# Processing Record 562 | isangel
# Processing Record 563 | kurilsk
# Processing Record 564 | winnemucca
# Processing Record 565 | nabire
# Processing Record 566 | marquette
# Processing Record 567 | maragua
# Processing Record 568 | aksarka
# Processing Record 569 | ryuo
# Processing Record 570 | seymchan
# Processing Record 571 | kushiro
# Processing Record 572 | tigil
# Processing Record 573 | wukari
# Processing Record 574 | kamenka
# Processing Record 575 | jutai
# Processing Record 576 | kodinsk
# Processing Record 577 | kamenskoye
# Processing Record 578 | roma
# Processing Record 579 | ovsyanka
# Processing Record 580 | bubaque
# Processing Record 581 | kelebia
# Processing Record 582 | prince rupert
# Processing Record 583 | emba
# Processing Record 584 | jacareacanga
# Processing Record 585 | abha
# Processing Record 586 | ganzhou
# Processing Record 587 | viedma
# Processing Record 588 | fortaleza
# Processing Record 589 | jaguarao
# Processing Record 590 | urucara
# Processing Record 591 | kaka
# Processing Record 592 | mount gambier
# Processing Record 593 | idaho falls
# Processing Record 594 | zamora
# Processing Record 595 | suraia
# Processing Record 596 | doha
# Processing Record 597 | whitianga
# Processing Record 598 | skagastrond
# Processing Record 599 | dolores
# Processing Record 600 | radlje ob dravi
# Processing Record 601 | grand gaube
# Processing Record 602 | attawapiskat
# Processing Record 603 | langsa
# Processing Record 604 | mattawa
# Processing Record 605 | san patricio
# Processing Record 606 | camacha
# Processing Record 607 | san andres
# Processing Record 608 | hobyo
# Processing Record 609 | umzimvubu
# Processing Record 610 | ardesen
# Processing Record 611 | zavitinsk
# Processing Record 612 | zlitan
# Processing Record 613 | todos santos
# Processing Record 614 | aleksandrov gay
# Processing Record 615 | edinet
# Processing Record 616 | zhangjiakou
# Processing Record 617 | aripuana
# Processing Record 618 | sept-iles
# Processing Record 619 | buta
# Processing Record 620 | los llanos de aridane
# Processing Record 621 | harrison
# Processing Record 622 | berbera
# Processing Record 623 | shambu

# %%
response_json
# Out:
# [{'coord': {'lon': 84.87, 'lat': 47.47},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 287.4,
#    'pressure': 1022.05,
#    'humidity': 39,
#    'temp_min': 287.4,
#    'temp_max': 287.4,
#    'sea_level': 1022.05,
#    'grnd_level': 923.5},
#   'wind': {'speed': 1.32, 'deg': 318.467},
#   'clouds': {'all': 10},
#   'dt': 1557202223,
#   'sys': {'message': 0.0051,
#    'country': 'KZ',
#    'sunrise': 1557183325,
#    'sunset': 1557236325},
#   'id': 1517060,
#   'name': 'Zaysan',
#   'cod': 200},
#  {'coord': {'lon': 80.68, 'lat': 7.35},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 301.2,
#    'pressure': 1011.17,
#    'humidity': 65,
#    'temp_min': 301.2,
#    'temp_max': 301.2,
#    'sea_level': 1011.17,
#    'grnd_level': 980.64},
#   'wind': {'speed': 2.86, 'deg': 223.938},
#   'clouds': {'all': 47},
#   'dt': 1557202223,
#   'sys': {'message': 0.0045,
#    'country': 'LK',
#    'sunrise': 1557188489,
#    'sunset': 1557233172},
#   'id': 1241622,
#   'name': 'Wattegama',
#   'cod': 200},
#  {'coord': {'lon': 0.71, 'lat': 49.65},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 278.63,
#    'pressure': 1019,
#    'humidity': 86,
#    'temp_min': 277.59,
#    'temp_max': 279.26},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 120},
#   'clouds': {'all': 0},
#   'dt': 1557202220,
#   'sys': {'type': 1,
#    'id': 6536,
#    'message': 0.0062,
#    'country': 'FR',
#    'sunrise': 1557203102,
#    'sunset': 1557256943},
#   'id': 3031871,
#   'name': 'Veraval',
#   'cod': 200},
#  {'coord': {'lon': 73.08, 'lat': -0.6},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 302.4,
#    'pressure': 1012.03,
#    'humidity': 72,
#    'temp_min': 302.4,
#    'temp_max': 302.4,
#    'sea_level': 1012.03,
#    'grnd_level': 1012.14},
#   'wind': {'speed': 3.59, 'deg': 172.418},
#   'rain': {'3h': 3.688},
#   'clouds': {'all': 78},
#   'dt': 1557202217,
#   'sys': {'message': 0.0043,
#    'country': 'MV',
#    'sunrise': 1557190890,
#    'sunset': 1557234420},
#   'id': 1282256,
#   'name': 'Hithadhoo',
#   'cod': 200},
#  {'coord': {'lon': 74.75, 'lat': 19.09},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 303.2,
#    'pressure': 1010.14,
#    'humidity': 25,
#    'temp_min': 303.2,
#    'temp_max': 303.2,
#    'sea_level': 1010.14,
#    'grnd_level': 926.16},
#   'wind': {'speed': 4, 'deg': 299.334},
#   'clouds': {'all': 0},
#   'dt': 1557202224,
#   'sys': {'message': 0.0047,
#    'country': 'IN',
#    'sunrise': 1557189004,
#    'sunset': 1557235504},
#   'id': 1279228,
#   'name': 'Ahmadnagar',
#   'cod': 200},
#  {'coord': {'lon': 30.79, 'lat': 59.7},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 278.68,
#    'pressure': 1008,
#    'humidity': 87,
#    'temp_min': 278.15,
#    'temp_max': 279.15},
#   'visibility': 9000,
#   'wind': {'speed': 2, 'deg': 30},
#   'clouds': {'all': 90},
#   'dt': 1557202024,
#   'sys': {'type': 1,
#    'id': 8926,
#    'message': 0.0068,
#    'country': 'RU',
#    'sunrise': 1557193297,
#    'sunset': 1557252311},
#   'id': 546105,
#   'name': 'Nikolskoye',
#   'cod': 200},
#  {'coord': {'lon': 138.6, 'lat': -33.21},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 292.5,
#    'pressure': 1012.46,
#    'humidity': 47,
#    'temp_min': 292.5,
#    'temp_max': 292.5,
#    'sea_level': 1012.46,
#    'grnd_level': 982.91},
#   'wind': {'speed': 8.5, 'deg': 278.518},
#   'clouds': {'all': 1},
#   'dt': 1557202224,
#   'sys': {'message': 0.005,
#    'country': 'AU',
#    'sunrise': 1557177784,
#    'sunset': 1557216077},
#   'id': 2069194,
#   'name': 'Jamestown',
#   'cod': 200},
#  {'coord': {'lon': -28.7, 'lat': 38.52},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 289.4,
#    'pressure': 1010.58,
#    'humidity': 80,
#    'temp_min': 289.4,
#    'temp_max': 289.4,
#    'sea_level': 1010.58,
#    'grnd_level': 1010.75},
#   'wind': {'speed': 6.87, 'deg': 300.53},
#   'clouds': {'all': 75},
#   'dt': 1557202224,
#   'sys': {'message': 0.0052,
#    'country': 'PT',
#    'sunrise': 1557211878,
#    'sunset': 1557262284},
#   'id': 3372707,
#   'name': 'Ribeira Grande',
#   'cod': 200},
#  {'coord': {'lon': -74.98, 'lat': 39.31},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 285.01,
#    'pressure': 1020,
#    'humidity': 87,
#    'temp_min': 283.71,
#    'temp_max': 286.15},
#   'visibility': 16093,
#   'wind': {'speed': 2.6, 'deg': 150},
#   'clouds': {'all': 0},
#   'dt': 1557202216,
#   'sys': {'type': 1,
#    'id': 9745,
#    'message': 0.0079,
#    'country': 'US',
#    'sunrise': 1557222876,
#    'sunset': 1557273500},
#   'id': 4501427,
#   'name': 'Port Elizabeth',
#   'cod': 200},
#  {'coord': {'lon': 130.99, 'lat': -25.24},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 297.15,
#    'pressure': 1020,
#    'humidity': 19,
#    'temp_min': 297.15,
#    'temp_max': 297.15},
#   'visibility': 10000,
#   'wind': {'speed': 6.7, 'deg': 180},
#   'clouds': {'all': 0},
#   'dt': 1557198000,
#   'sys': {'type': 1,
#    'id': 9487,
#    'message': 0.006,
#    'country': 'AU',
#    'sunrise': 1557178868,
#    'sunset': 1557218645},
#   'id': 6355222,
#   'name': 'Yulara',
#   'cod': 200},
#  {'coord': {'lon': 13.84, 'lat': -18.06},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 290.8,
#    'pressure': 1015.18,
#    'humidity': 45,
#    'temp_min': 290.8,
#    'temp_max': 290.8,
#    'sea_level': 1015.18,
#    'grnd_level': 903.66},
#   'wind': {'speed': 0.74, 'deg': 241.851},
#   'clouds': {'all': 24},
#   'dt': 1557202225,
#   'sys': {'message': 0.005,
#    'country': 'NA',
#    'sunrise': 1557206402,
#    'sunset': 1557247342},
#   'id': 3354077,
#   'name': 'Opuwo',
#   'cod': 200},
#  {'coord': {'lon': -94.76, 'lat': 39.95},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 287.61,
#    'pressure': 1016,
#    'humidity': 87,
#    'temp_min': 286.15,
#    'temp_max': 289.15},
#   'visibility': 16093,
#   'wind': {'speed': 5.7, 'deg': 60},
#   'clouds': {'all': 40},
#   'dt': 1557202119,
#   'sys': {'type': 1,
#    'id': 4022,
#    'message': 0.0069,
#    'country': 'US',
#    'sunrise': 1557141203,
#    'sunset': 1557191874},
#   'id': 4407665,
#   'name': 'Kodiak',
#   'cod': 200},
#  {'coord': {'lon': -41.05, 'lat': -21.64},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 294.8,
#    'pressure': 1014.9,
#    'humidity': 88,
#    'temp_min': 294.8,
#    'temp_max': 294.8,
#    'sea_level': 1014.9,
#    'grnd_level': 998.85},
#   'wind': {'speed': 1.88, 'deg': 298.91},
#   'clouds': {'all': 17},
#   'dt': 1557202223,
#   'sys': {'message': 0.0045,
#    'country': 'BR',
#    'sunrise': 1557219867,
#    'sunset': 1557260222},
#   'id': 3448903,
#   'name': 'Sao Joao da Barra',
#   'cod': 200},
#  {'coord': {'lon': -79.15, 'lat': -7.84},
#   'weather': [{'id': 701,
#     'main': 'Mist',
#     'description': 'mist',
#     'icon': '50n'}],
#   'base': 'stations',
#   'main': {'temp': 294.15,
#    'pressure': 1011,
#    'humidity': 88,
#    'temp_min': 294.15,
#    'temp_max': 294.15},
#   'visibility': 8000,
#   'wind': {'speed': 4.6, 'deg': 140},
#   'clouds': {'all': 90},
#   'dt': 1557198000,
#   'sys': {'type': 1,
#    'id': 8690,
#    'message': 0.0043,
#    'country': 'PE',
#    'sunrise': 1557141544,
#    'sunset': 1557184040},
#   'id': 3698359,
#   'name': 'Chicama',
#   'cod': 200},
#  {'coord': {'lon': 25.59, 'lat': -32.72},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 293.5,
#    'pressure': 1017.89,
#    'humidity': 36,
#    'temp_min': 293.5,
#    'temp_max': 293.5,
#    'sea_level': 1017.89,
#    'grnd_level': 944.56},
#   'wind': {'speed': 2.38, 'deg': 355.511},
#   'clouds': {'all': 100},
#   'dt': 1557202226,
#   'sys': {'message': 0.0054,
#    'country': 'ZA',
#    'sunrise': 1557204871,
#    'sunset': 1557243233},
#   'id': 954161,
#   'name': 'Somerset East',
#   'cod': 200},
#  {'coord': {'lon': 147.33, 'lat': -42.88},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 287.42,
#    'pressure': 1007,
#    'humidity': 51,
#    'temp_min': 285.93,
#    'temp_max': 288.15},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 320},
#   'clouds': {'all': 75},
#   'dt': 1557201974,
#   'sys': {'type': 1,
#    'id': 9545,
#    'message': 0.0054,
#    'country': 'AU',
#    'sunrise': 1557176804,
#    'sunset': 1557212867},
#   'id': 2163355,
#   'name': 'Hobart',
#   'cod': 200},
#  {'coord': {'lon': 38.73, 'lat': 8.96},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 287.15,
#    'pressure': 1026,
#    'humidity': 58,
#    'temp_min': 287.15,
#    'temp_max': 287.15},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 120},
#   'clouds': {'all': 20},
#   'dt': 1557198000,
#   'sys': {'type': 1,
#    'id': 2453,
#    'message': 0.0049,
#    'country': 'ET',
#    'sunrise': 1557198437,
#    'sunset': 1557243360},
#   'id': 344979,
#   'name': 'Lebu',
#   'cod': 200},
#  {'coord': {'lon': 173.16, 'lat': -35.17},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 292.59,
#    'pressure': 1023,
#    'humidity': 98,
#    'temp_min': 292.59,
#    'temp_max': 292.59},
#   'wind': {'speed': 4.68, 'deg': 42.532},
#   'clouds': {'all': 1},
#   'dt': 1557202109,
#   'sys': {'type': 3,
#    'id': 2016422,
#    'message': 0.0046,
#    'country': 'NZ',
#    'sunrise': 1557169688,
#    'sunset': 1557207585},
#   'id': 2194098,
#   'name': 'Ahipara',
#   'cod': 200},
#  {'coord': {'lon': -139.03, 'lat': -9.8},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 301.5,
#    'pressure': 1008.07,
#    'humidity': 77,
#    'temp_min': 301.5,
#    'temp_max': 301.5,
#    'sea_level': 1008.07,
#    'grnd_level': 1007.93},
#   'wind': {'speed': 8.15, 'deg': 91.695},
#   'rain': {'3h': 0.188},
#   'clouds': {'all': 100},
#   'dt': 1557202227,
#   'sys': {'message': 0.005,
#    'country': 'PF',
#    'sunrise': 1557156058,
#    'sunset': 1557198267},
#   'id': 4020109,
#   'name': 'Atuona',
#   'cod': 200},
#  {'coord': {'lon': -73.75, 'lat': 42.65},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 286.74,
#    'pressure': 1017,
#    'humidity': 100,
#    'temp_min': 282.59,
#    'temp_max': 290.15},
#   'visibility': 16093,
#   'wind': {'speed': 1.5, 'deg': 270},
#   'clouds': {'all': 1},
#   'dt': 1557202115,
#   'sys': {'type': 1,
#    'id': 5137,
#    'message': 0.0073,
#    'country': 'US',
#    'sunrise': 1557222123,
#    'sunset': 1557273662},
#   'id': 5106834,
#   'name': 'Albany',
#   'cod': 200},
#  {'coord': {'lon': 34.33, 'lat': 56.26},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 283.7,
#    'pressure': 1007.1,
#    'humidity': 94,
#    'temp_min': 283.7,
#    'temp_max': 283.7,
#    'sea_level': 1007.1,
#    'grnd_level': 978.37},
#   'wind': {'speed': 2.64, 'deg': 150.648},
#   'clouds': {'all': 33},
#   'dt': 1557202227,
#   'sys': {'message': 0.0047,
#    'country': 'RU',
#    'sunrise': 1557193521,
#    'sunset': 1557250387},
#   'id': 499717,
#   'name': 'Rzhev',
#   'cod': 200},
#  {'coord': {'lon': -133.03, 'lat': 69.44},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 268.15,
#    'pressure': 1013,
#    'humidity': 85,
#    'temp_min': 268.15,
#    'temp_max': 268.15},
#   'visibility': 24140,
#   'wind': {'speed': 6.7, 'deg': 50},
#   'clouds': {'all': 90},
#   'dt': 1557198000,
#   'sys': {'type': 1,
#    'id': 942,
#    'message': 0.0056,
#    'country': 'CA',
#    'sunrise': 1557140512,
#    'sunset': 1557210933},
#   'id': 6170031,
#   'name': 'Tuktoyaktuk',
#   'cod': 200},
#  {'coord': {'lon': -39.03, 'lat': -3.41},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 298.91,
#    'pressure': 1011,
#    'humidity': 83,
#    'temp_min': 298.71,
#    'temp_max': 299.15},
#   'visibility': 10000,
#   'wind': {'speed': 1, 'deg': 190},
#   'clouds': {'all': 0},
#   'dt': 1557202089,
#   'sys': {'type': 1,
#    'id': 8363,
#    'message': 0.006,
#    'country': 'BR',
#    'sunrise': 1557217999,
#    'sunset': 1557261122},
#   'id': 3393115,
#   'name': 'Paracuru',
#   'cod': 200},
#  {'coord': {'lon': -67.52, 'lat': -46.43},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 282.5,
#    'pressure': 1013.94,
#    'humidity': 55,
#    'temp_min': 282.5,
#    'temp_max': 282.5,
#    'sea_level': 1013.94,
#    'grnd_level': 978.88},
#   'wind': {'speed': 2.35, 'deg': 308.473},
#   'clouds': {'all': 0},
#   'dt': 1557202228,
#   'sys': {'message': 0.0049,
#    'country': 'AR',
#    'sunrise': 1557228918,
#    'sunset': 1557263877},
#   'id': 3863379,
#   'name': 'Mar del Plata',
#   'cod': 200},
#  {'coord': {'lon': 22.13, 'lat': -30.97},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 291,
#    'pressure': 1018.55,
#    'humidity': 33,
#    'temp_min': 291,
#    'temp_max': 291,
#    'sea_level': 1018.55,
#    'grnd_level': 873.45},
#   'wind': {'speed': 4.12, 'deg': 6.182},
#   'clouds': {'all': 100},
#   'dt': 1557202228,
#   'sys': {'message': 0.0053,
#    'country': 'ZA',
#    'sunrise': 1557205529,
#    'sunset': 1557244236},
#   'id': 1014034,
#   'name': 'Carnarvon',
#   'cod': 200},
#  {'coord': {'lon': -70.91, 'lat': -53.16},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 283.68,
#    'pressure': 1005,
#    'humidity': 66,
#    'temp_min': 283.15,
#    'temp_max': 284.15},
#   'visibility': 10000,
#   'wind': {'speed': 8.2, 'deg': 300},
#   'clouds': {'all': 75},
#   'dt': 1557201792,
#   'sys': {'type': 1,
#    'id': 8487,
#    'message': 0.004,
#    'country': 'CL',
#    'sunrise': 1557230935,
#    'sunset': 1557263488},
#   'id': 3874787,
#   'name': 'Punta Arenas',
#   'cod': 200},
#  {'coord': {'lon': 39.26, 'lat': -15.12},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 293.15,
#    'pressure': 1021,
#    'humidity': 94,
#    'temp_min': 293.15,
#    'temp_max': 293.15},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 220},
#   'clouds': {'all': 20},
#   'dt': 1557198000,
#   'sys': {'type': 1,
#    'id': 2191,
#    'message': 0.0045,
#    'country': 'MZ',
#    'sunrise': 1557200072,
#    'sunset': 1557241471},
#   'id': 1033356,
#   'name': 'Nampula',
#   'cod': 200},
#  {'coord': {'lon': -68.31, 'lat': -54.81},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 284.15,
#    'pressure': 1001,
#    'humidity': 66,
#    'temp_min': 284.15,
#    'temp_max': 284.15},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 250},
#   'clouds': {'all': 40},
#   'dt': 1557198000,
#   'sys': {'type': 1,
#    'id': 8303,
#    'message': 0.0053,
#    'country': 'AR',
#    'sunrise': 1557230670,
#    'sunset': 1557262504},
#   'id': 3833367,
#   'name': 'Ushuaia',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -67.92, 'lat': -17.23},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 281.4,
#    'pressure': 1022.99,
#    'humidity': 63,
#    'temp_min': 281.4,
#    'temp_max': 281.4,
#    'sea_level': 1022.99,
#    'grnd_level': 654.05},
#   'wind': {'speed': 4.56, 'deg': 1.307},
#   'clouds': {'all': 23},
#   'dt': 1557202229,
#   'sys': {'message': 0.0047,
#    'country': 'BO',
#    'sunrise': 1557225963,
#    'sunset': 1557267024},
#   'id': 3908339,
#   'name': 'Patacamaya',
#   'cod': 200},
#  {'coord': {'lon': -56.15, 'lat': 72.79},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 273.6,
#    'pressure': 1027.85,
#    'humidity': 87,
#    'temp_min': 273.6,
#    'temp_max': 273.6,
#    'sea_level': 1027.85,
#    'grnd_level': 1027.31},
#   'wind': {'speed': 0.81, 'deg': 231.771},
#   'clouds': {'all': 43},
#   'dt': 1557202229,
#   'sys': {'message': 0.0042, 'country': 'GL', 'sunrise': 0, 'sunset': 0},
#   'id': 3418910,
#   'name': 'Upernavik',
#   'cod': 200},
#  {'coord': {'lon': -111.68, 'lat': 43.97},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 287.09,
#    'pressure': 1011,
#    'humidity': 38,
#    'temp_min': 284.15,
#    'temp_max': 289.15},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 210},
#   'clouds': {'all': 75},
#   'dt': 1557202178,
#   'sys': {'type': 1,
#    'id': 5735,
#    'message': 0.005,
#    'country': 'US',
#    'sunrise': 1557144700,
#    'sunset': 1557196498},
#   'id': 5606187,
#   'name': 'Saint Anthony',
#   'cod': 200},
#  {'coord': {'lon': 168.86, 'lat': -46.19},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 287.59,
#    'pressure': 1025,
#    'humidity': 88,
#    'temp_min': 287.59,
#    'temp_max': 287.59},
#   'wind': {'speed': 0.86, 'deg': 120.084},
#   'clouds': {'all': 100},
#   'dt': 1557202205,
#   'sys': {'type': 3,
#    'id': 2008959,
#    'message': 0.0056,
#    'country': 'NZ',
#    'sunrise': 1557172101,
#    'sunset': 1557207236},
#   'id': 6201424,
#   'name': 'Mataura',
#   'cod': 200},
#  {'coord': {'lon': -134.97, 'lat': -23.12},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 298.3,
#    'pressure': 1016.19,
#    'humidity': 81,
#    'temp_min': 298.3,
#    'temp_max': 298.3,
#    'sea_level': 1016.19,
#    'grnd_level': 1016.01},
#   'wind': {'speed': 8.3, 'deg': 92.354},
#   'clouds': {'all': 3},
#   'dt': 1557202230,
#   'sys': {'message': 0.0046,
#    'country': 'PF',
#    'sunrise': 1557156111,
#    'sunset': 1557196265},
#   'id': 4030556,
#   'name': 'Rikitea',
#   'cod': 200},
#  {'coord': {'lon': 115.24, 'lat': 5.28},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 304.97,
#    'pressure': 1010,
#    'humidity': 70,
#    'temp_min': 304.82,
#    'temp_max': 305.15},
#   'visibility': 10000,
#   'wind': {'speed': 2.6},
#   'clouds': {'all': 75},
#   'dt': 1557199800,
#   'sys': {'type': 1,
#    'id': 9372,
#    'message': 0.0054,
#    'country': 'BN',
#    'sunrise': 1557180348,
#    'sunset': 1557224726},
#   'id': 1733782,
#   'name': 'Victoria',
#   'cod': 200},
#  {'coord': {'lon': 54.1, 'lat': 17.01},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 299.15,
#    'pressure': 1011,
#    'humidity': 34,
#    'temp_min': 299.15,
#    'temp_max': 299.15},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 360},
#   'clouds': {'all': 0},
#   'dt': 1557197400,
#   'sys': {'type': 1,
#    'id': 7562,
#    'message': 0.0047,
#    'country': 'OM',
#    'sunrise': 1557194128,
#    'sunset': 1557240292},
#   'id': 286621,
#   'name': 'Salalah',
#   'cod': 200},
#  {'coord': {'lon': 78.14, 'lat': 15.88},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 310.7,
#    'pressure': 1007.7,
#    'humidity': 21,
#    'temp_min': 310.7,
#    'temp_max': 310.7,
#    'sea_level': 1007.7,
#    'grnd_level': 974.59},
#   'wind': {'speed': 7.34, 'deg': 267.65},
#   'clouds': {'all': 24},
#   'dt': 1557202231,
#   'sys': {'message': 0.0051,
#    'country': 'IN',
#    'sunrise': 1557188450,
#    'sunset': 1557234431},
#   'id': 1279074,
#   'name': 'Alampur',
#   'cod': 200},
#  {'coord': {'lon': 6.55, 'lat': 9.62},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 301.7,
#    'pressure': 1010.3,
#    'humidity': 68,
#    'temp_min': 301.7,
#    'temp_max': 301.7,
#    'sea_level': 1010.3,
#    'grnd_level': 984.46},
#   'wind': {'speed': 3.14, 'deg': 207.226},
#   'clouds': {'all': 94},
#   'dt': 1557202231,
#   'sys': {'message': 0.0059,
#    'country': 'NG',
#    'sunrise': 1557206109,
#    'sunset': 1557251134},
#   'id': 2330100,
#   'name': 'Minna',
#   'cod': 200},
#  {'coord': {'lon': -0.5, 'lat': 43.89},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 279.35,
#    'pressure': 1016,
#    'humidity': 86,
#    'temp_min': 278.15,
#    'temp_max': 280.37},
#   'visibility': 10000,
#   'wind': {'speed': 1, 'deg': 60},
#   'clouds': {'all': 0},
#   'dt': 1557202225,
#   'sys': {'type': 1,
#    'id': 6457,
#    'message': 0.0062,
#    'country': 'FR',
#    'sunrise': 1557204375,
#    'sunset': 1557256252},
#   'id': 2992771,
#   'name': 'Mont-de-Marsan',
#   'cod': 200},
#  {'coord': {'lon': -45.24, 'lat': 60.14},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 277.3,
#    'pressure': 1023.2,
#    'humidity': 82,
#    'temp_min': 277.3,
#    'temp_max': 277.3,
#    'sea_level': 1023.2,
#    'grnd_level': 1019.69},
#   'wind': {'speed': 3.02, 'deg': 52.887},
#   'clouds': {'all': 0},
#   'dt': 1557202231,
#   'sys': {'message': 0.0048,
#    'country': 'GL',
#    'sunrise': 1557211354,
#    'sunset': 1557270747},
#   'id': 3421765,
#   'name': 'Nanortalik',
#   'cod': 200},
#  {'coord': {'lon': -53.11, 'lat': 48.65},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 274.82,
#    'pressure': 1011,
#    'humidity': 86,
#    'temp_min': 274.82,
#    'temp_max': 274.82},
#   'wind': {'speed': 6.26, 'deg': 280, 'gust': 9.39},
#   'clouds': {'all': 11},
#   'dt': 1557201710,
#   'sys': {'type': 3,
#    'id': 2011050,
#    'message': 0.0057,
#    'country': 'CA',
#    'sunrise': 1557216194,
#    'sunset': 1557269684},
#   'id': 5905393,
#   'name': 'Bonavista',
#   'cod': 200},
#  {'coord': {'lon': 26.89, 'lat': -33.59},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 290.37,
#    'pressure': 1016,
#    'humidity': 97,
#    'temp_min': 290.37,
#    'temp_max': 290.37},
#   'wind': {'speed': 1.75, 'deg': 311.37},
#   'clouds': {'all': 96},
#   'dt': 1557201752,
#   'sys': {'type': 3,
#    'id': 2011314,
#    'message': 0.0048,
#    'country': 'ZA',
#    'sunrise': 1557204647,
#    'sunset': 1557242833},
#   'id': 964432,
#   'name': 'Port Alfred',
#   'cod': 200},
#  {'coord': {'lon': 49.87, 'lat': 11.47},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 303.3,
#    'pressure': 1011.97,
#    'humidity': 69,
#    'temp_min': 303.3,
#    'temp_max': 303.3,
#    'sea_level': 1011.97,
#    'grnd_level': 1011.2},
#   'wind': {'speed': 0.16, 'deg': 287.438},
#   'clouds': {'all': 0},
#   'dt': 1557202232,
#   'sys': {'message': 0.0061,
#    'country': 'SO',
#    'sunrise': 1557195575,
#    'sunset': 1557240875},
#   'id': 53157,
#   'name': 'Qandala',
#   'cod': 200},
#  {'coord': {'lon': 147.9, 'lat': 70.62},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 270.5,
#    'pressure': 1010.58,
#    'humidity': 94,
#    'temp_min': 270.5,
#    'temp_max': 270.5,
#    'sea_level': 1010.58,
#    'grnd_level': 1009.2},
#   'wind': {'speed': 6.26, 'deg': 107.767},
#   'clouds': {'all': 100},
#   'dt': 1557202232,
#   'sys': {'message': 0.0052,
#    'country': 'RU',
#    'sunrise': 1557157879,
#    'sunset': 1557231519},
#   'id': 2126123,
#   'name': 'Chokurdakh',
#   'cod': 200},
#  {'coord': {'lon': 39.51, 'lat': 68.05},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 271.7,
#    'pressure': 1023.42,
#    'humidity': 74,
#    'temp_min': 271.7,
#    'temp_max': 271.7,
#    'sea_level': 1023.42,
#    'grnd_level': 1006.86},
#   'wind': {'speed': 3.97, 'deg': 230.165},
#   'clouds': {'all': 0},
#   'dt': 1557202232,
#   'sys': {'message': 0.0057,
#    'country': 'RU',
#    'sunrise': 1557186693,
#    'sunset': 1557254729},
#   'id': 556268,
#   'name': 'Ostrovnoy',
#   'cod': 200},
#  {'coord': {'lon': -73.83, 'lat': -41.87},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 277.15,
#    'pressure': 1019,
#    'humidity': 100,
#    'temp_min': 277.15,
#    'temp_max': 277.15},
#   'wind': {'speed': 2.1, 'deg': 190},
#   'clouds': {'all': 20},
#   'dt': 1557198000,
#   'sys': {'type': 1,
#    'id': 8512,
#    'message': 0.0046,
#    'country': 'CL',
#    'sunrise': 1557229789,
#    'sunset': 1557266035},
#   'id': 3899695,
#   'name': 'Ancud',
#   'cod': 200},
#  {'coord': {'lon': -151.75, 'lat': -16.48},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 301.7,
#    'pressure': 1008.65,
#    'humidity': 64,
#    'temp_min': 301.7,
#    'temp_max': 301.7,
#    'sea_level': 1008.65,
#    'grnd_level': 1008.72},
#   'wind': {'speed': 2.65, 'deg': 60.397},
#   'clouds': {'all': 81},
#   'dt': 1557202233,
#   'sys': {'message': 0.0043,
#    'country': 'PF',
#    'sunrise': 1557159610,
#    'sunset': 1557200820},
#   'id': 4034551,
#   'name': 'Faanui',
#   'cod': 200},
#  {'coord': {'lon': -44.87, 'lat': -1.82},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 296.8,
#    'pressure': 1012.96,
#    'humidity': 98,
#    'temp_min': 296.8,
#    'temp_max': 296.8,
#    'sea_level': 1012.96,
#    'grnd_level': 1009.01},
#   'wind': {'speed': 0.43, 'deg': 88.812},
#   'clouds': {'all': 100},
#   'dt': 1557202233,
#   'sys': {'message': 0.0066,
#    'country': 'BR',
#    'sunrise': 1557219285,
#    'sunset': 1557262638},
#   'id': 3401148,
#   'name': 'Cururupu',
#   'cod': 200},
#  {'coord': {'lon': -70.1, 'lat': 41.28},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 278.75,
#    'pressure': 1020,
#    'humidity': 87,
#    'temp_min': 276.48,
#    'temp_max': 280.37},
#   'visibility': 16093,
#   'wind': {'speed': 3.6, 'deg': 20},
#   'clouds': {'all': 1},
#   'dt': 1557202222,
#   'sys': {'type': 1,
#    'id': 3218,
#    'message': 0.0082,
#    'country': 'US',
#    'sunrise': 1557221442,
#    'sunset': 1557272591},
#   'id': 4944903,
#   'name': 'Nantucket',
#   'cod': 200},
#  {'coord': {'lon': -91.49, 'lat': 18.78},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 302.1,
#    'pressure': 1010.01,
#    'humidity': 81,
#    'temp_min': 302.1,
#    'temp_max': 302.1,
#    'sea_level': 1010.01,
#    'grnd_level': 1009.87},
#   'wind': {'speed': 6.72, 'deg': 48.346},
#   'clouds': {'all': 30},
#   'dt': 1557202233,
#   'sys': {'message': 0.0044,
#    'country': 'MX',
#    'sunrise': 1557142543,
#    'sunset': 1557188964},
#   'id': 3526766,
#   'name': 'Isla Aguada',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 30.29, 'lat': 36.37},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 277.7,
#    'pressure': 1011.73,
#    'humidity': 90,
#    'temp_min': 277.7,
#    'temp_max': 277.7,
#    'sea_level': 1011.73,
#    'grnd_level': 841.9},
#   'wind': {'speed': 1.83, 'deg': 339.293},
#   'clouds': {'all': 6},
#   'dt': 1557202234,
#   'sys': {'message': 0.0045,
#    'country': 'TR',
#    'sunrise': 1557197992,
#    'sunset': 1557247856},
#   'id': 305681,
#   'name': 'Kumluca',
#   'cod': 200},
#  {'coord': {'lon': 139.9, 'lat': 69.3},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 272.9,
#    'pressure': 1007.14,
#    'humidity': 92,
#    'temp_min': 272.9,
#    'temp_max': 272.9,
#    'sea_level': 1007.14,
#    'grnd_level': 942.67},
#   'wind': {'speed': 1.73, 'deg': 157.041},
#   'clouds': {'all': 1},
#   'dt': 1557202234,
#   'sys': {'message': 0.0041,
#    'country': 'RU',
#    'sunrise': 1557161476,
#    'sunset': 1557231761},
#   'id': 2028164,
#   'name': 'Deputatskiy',
#   'cod': 200},
#  {'coord': {'lon': 153.13, 'lat': -30.3},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 296.65,
#    'pressure': 1014,
#    'humidity': 60,
#    'temp_min': 296.15,
#    'temp_max': 297.15},
#   'wind': {'speed': 3.6, 'deg': 180},
#   'clouds': {'all': 0},
#   'dt': 1557202105,
#   'sys': {'type': 1,
#    'id': 9521,
#    'message': 0.0053,
#    'country': 'AU',
#    'sunrise': 1557174010,
#    'sunset': 1557212877},
#   'id': 2171085,
#   'name': 'Coffs Harbour',
#   'cod': 200},
#  {'coord': {'lon': 136.9, 'lat': 37.4},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 286.15,
#    'pressure': 1014,
#    'humidity': 24,
#    'temp_min': 286.15,
#    'temp_max': 286.15},
#   'visibility': 10000,
#   'wind': {'speed': 2.6},
#   'clouds': {'all': 20},
#   'dt': 1557198000,
#   'sys': {'type': 1,
#    'id': 8022,
#    'message': 0.0048,
#    'country': 'JP',
#    'sunrise': 1557172301,
#    'sunset': 1557222376},
#   'id': 1848976,
#   'name': 'Wajima',
#   'cod': 200},
#  {'coord': {'lon': 122.67, 'lat': 11},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 307.9,
#    'pressure': 1009.03,
#    'humidity': 43,
#    'temp_min': 307.9,
#    'temp_max': 307.9,
#    'sea_level': 1009.03,
#    'grnd_level': 994.25},
#   'wind': {'speed': 3.56, 'deg': 223.806},
#   'clouds': {'all': 100},
#   'dt': 1557202234,
#   'sys': {'message': 0.0048,
#    'country': 'PH',
#    'sunrise': 1557178142,
#    'sunset': 1557223365},
#   'id': 1714733,
#   'name': 'Dingle',
#   'cod': 200},
#  {'coord': {'lon': -60.23, 'lat': -38.31},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 281,
#    'pressure': 1023.8,
#    'humidity': 77,
#    'temp_min': 281,
#    'temp_max': 281,
#    'sea_level': 1023.8,
#    'grnd_level': 1011.12},
#   'wind': {'speed': 2.38, 'deg': 49.167},
#   'clouds': {'all': 0},
#   'dt': 1557202235,
#   'sys': {'message': 0.0059,
#    'country': 'AR',
#    'sunrise': 1557226084,
#    'sunset': 1557263212},
#   'id': 3833859,
#   'name': 'Barrow',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 155.63, 'lat': -6.22},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 304.6,
#    'pressure': 1006.93,
#    'humidity': 57,
#    'temp_min': 304.6,
#    'temp_max': 304.6,
#    'sea_level': 1006.93,
#    'grnd_level': 1010.3},
#   'wind': {'speed': 2.14, 'deg': 52.518},
#   'clouds': {'all': 14},
#   'dt': 1557202235,
#   'sys': {'message': 0.0048,
#    'country': 'PG',
#    'sunrise': 1557171482,
#    'sunset': 1557214205},
#   'id': 2094027,
#   'name': 'Kieta',
#   'cod': 200},
#  {'coord': {'lon': -51.74, 'lat': 64.17},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 279.93,
#    'pressure': 1022,
#    'humidity': 65,
#    'temp_min': 279.82,
#    'temp_max': 280.15},
#   'wind': {'speed': 2.6, 'deg': 20},
#   'clouds': {'all': 59},
#   'dt': 1557197561,
#   'sys': {'type': 1,
#    'id': 86,
#    'message': 0.0087,
#    'country': 'GL',
#    'sunrise': 1557211143,
#    'sunset': 1557274078},
#   'id': 3421319,
#   'name': 'Nuuk',
#   'cod': 200},
#  {'coord': {'lon': 120.52, 'lat': 17.54},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 305.5,
#    'pressure': 1007.88,
#    'humidity': 53,
#    'temp_min': 305.5,
#    'temp_max': 305.5,
#    'sea_level': 1007.88,
#    'grnd_level': 995.26},
#   'wind': {'speed': 3.48, 'deg': 234.066},
#   'rain': {'3h': 1.062},
#   'clouds': {'all': 91},
#   'dt': 1557202235,
#   'sys': {'message': 0.0045,
#    'country': 'PH',
#    'sunrise': 1557178149,
#    'sunset': 1557224390},
#   'id': 1688687,
#   'name': 'San Quintin',
#   'cod': 200},
#  {'coord': {'lon': -158.09, 'lat': 21.35},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 296.62,
#    'pressure': 1008,
#    'humidity': 64,
#    'temp_min': 294.82,
#    'temp_max': 297.59},
#   'visibility': 16093,
#   'wind': {'speed': 3.1, 'deg': 270},
#   'clouds': {'all': 1},
#   'dt': 1557202009,
#   'sys': {'type': 1,
#    'id': 7868,
#    'message': 0.008,
#    'country': 'US',
#    'sunrise': 1557158308,
#    'sunset': 1557205166},
#   'id': 5850554,
#   'name': 'Makakilo City',
#   'cod': 200},
#  {'coord': {'lon': 118.58, 'lat': -20.31},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 306.15,
#    'pressure': 1014,
#    'humidity': 21,
#    'temp_min': 306.15,
#    'temp_max': 306.15},
#   'visibility': 10000,
#   'wind': {'speed': 11.3, 'deg': 110},
#   'clouds': {'all': 0},
#   'dt': 1557199800,
#   'sys': {'type': 1,
#    'id': 9585,
#    'message': 0.0053,
#    'country': 'AU',
#    'sunrise': 1557181437,
#    'sunset': 1557222033},
#   'id': 2063042,
#   'name': 'Port Hedland',
#   'cod': 200},
#  {'coord': {'lon': -15.05, 'lat': 13.79},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 303.7,
#    'pressure': 1009.86,
#    'humidity': 24,
#    'temp_min': 303.7,
#    'temp_max': 303.7,
#    'sea_level': 1009.86,
#    'grnd_level': 1006.08},
#   'wind': {'speed': 4.39, 'deg': 346.486},
#   'clouds': {'all': 42},
#   'dt': 1557202236,
#   'sys': {'message': 0.005,
#    'country': 'GM',
#    'sunrise': 1557210974,
#    'sunset': 1557256637},
#   'id': 2413070,
#   'name': 'Nioro',
#   'cod': 200},
#  {'coord': {'lon': -161.76, 'lat': 60.79},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 282.15,
#    'pressure': 1000,
#    'humidity': 66,
#    'temp_min': 281.15,
#    'temp_max': 283.15},
#   'visibility': 16093,
#   'wind': {'speed': 3.64, 'deg': 192.481},
#   'clouds': {'all': 1},
#   'dt': 1557201180,
#   'sys': {'type': 1,
#    'id': 7640,
#    'message': 0.0055,
#    'country': 'US',
#    'sunrise': 1557152784,
#    'sunset': 1557212451},
#   'id': 5880568,
#   'name': 'Bethel',
#   'cod': 200},
#  {'coord': {'lon': 8.56, 'lat': 45.76},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 278.94,
#    'pressure': 1017,
#    'humidity': 74,
#    'temp_min': 274.82,
#    'temp_max': 283.15},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 10},
#   'clouds': {'all': 0},
#   'dt': 1557202224,
#   'sys': {'type': 1,
#    'id': 6734,
#    'message': 0.0057,
#    'country': 'IT',
#    'sunrise': 1557201909,
#    'sunset': 1557254369},
#   'id': 3182812,
#   'name': 'Arona',
#   'cod': 200},
#  {'coord': {'lon': -51.99, 'lat': -6.64},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 295.1,
#    'pressure': 1014.02,
#    'humidity': 84,
#    'temp_min': 295.1,
#    'temp_max': 295.1,
#    'sea_level': 1014.02,
#    'grnd_level': 973.52},
#   'wind': {'speed': 1.75, 'deg': 90.033},
#   'clouds': {'all': 48},
#   'dt': 1557202237,
#   'sys': {'message': 0.0046,
#    'country': 'BR',
#    'sunrise': 1557221344,
#    'sunset': 1557263997},
#   'id': 3388847,
#   'name': 'Sao Felix do Xingu',
#   'cod': 200},
#  {'coord': {'lon': 149.07, 'lat': -23.58},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 297.5,
#    'pressure': 1015.75,
#    'humidity': 28,
#    'temp_min': 297.5,
#    'temp_max': 297.5,
#    'sea_level': 1015.75,
#    'grnd_level': 991.04},
#   'wind': {'speed': 1.99, 'deg': 69.072},
#   'clouds': {'all': 0},
#   'dt': 1557202237,
#   'sys': {'message': 0.0051,
#    'country': 'AU',
#    'sunrise': 1557174386,
#    'sunset': 1557214450},
#   'id': 2175403,
#   'name': 'Bluff',
#   'cod': 200},
#  {'coord': {'lon': 12.77, 'lat': 26.59},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 297.4,
#    'pressure': 1016.47,
#    'humidity': 12,
#    'temp_min': 297.4,
#    'temp_max': 297.4,
#    'sea_level': 1016.47,
#    'grnd_level': 953.23},
#   'wind': {'speed': 5.62, 'deg': 46.767},
#   'clouds': {'all': 0},
#   'dt': 1557202237,
#   'sys': {'message': 0.0051,
#    'country': 'LY',
#    'sunrise': 1557203216,
#    'sunset': 1557251041},
#   'id': 2219235,
#   'name': 'Awbari',
#   'cod': 200},
#  {'coord': {'lon': -54.34, 'lat': -34.48},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 282.5,
#    'pressure': 1022.22,
#    'humidity': 85,
#    'temp_min': 282.5,
#    'temp_max': 282.5,
#    'sea_level': 1022.22,
#    'grnd_level': 1010.37},
#   'wind': {'speed': 1.46, 'deg': 172.773},
#   'clouds': {'all': 0},
#   'dt': 1557202238,
#   'sys': {'message': 0.0047,
#    'country': 'UY',
#    'sunrise': 1557224245,
#    'sunset': 1557262224},
#   'id': 3440777,
#   'name': 'Rocha',
#   'cod': 200},
#  {'coord': {'lon': 167.72, 'lat': -45.41},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 288.6,
#    'pressure': 1023.76,
#    'humidity': 58,
#    'temp_min': 288.6,
#    'temp_max': 288.6,
#    'sea_level': 1023.76,
#    'grnd_level': 945.81},
#   'wind': {'speed': 0.89, 'deg': 9.937},
#   'clouds': {'all': 88},
#   'dt': 1557202238,
#   'sys': {'message': 0.0044,
#    'country': 'NZ',
#    'sunrise': 1557172259,
#    'sunset': 1557207625},
#   'id': 2181625,
#   'name': 'Te Anau',
#   'cod': 200},
#  {'coord': {'lon': -99.88, 'lat': 16.86},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 299.15,
#    'pressure': 1011,
#    'humidity': 83,
#    'temp_min': 299.15,
#    'temp_max': 299.15},
#   'visibility': 8047,
#   'wind': {'speed': 3.6, 'deg': 270},
#   'clouds': {'all': 40},
#   'dt': 1557197400,
#   'sys': {'type': 1,
#    'id': 7103,
#    'message': 0.005,
#    'country': 'MX',
#    'sunrise': 1557144710,
#    'sunset': 1557190824},
#   'id': 3533462,
#   'name': 'Acapulco',
#   'cod': 200},
#  {'coord': {'lon': -61.45, 'lat': 10.24},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 298.82,
#    'pressure': 1015,
#    'humidity': 88,
#    'temp_min': 297.59,
#    'temp_max': 299.26},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 110},
#   'clouds': {'all': 20},
#   'dt': 1557202207,
#   'sys': {'type': 1,
#    'id': 8810,
#    'message': 0.0048,
#    'country': 'TT',
#    'sunrise': 1557222379,
#    'sunset': 1557267502},
#   'id': 3573739,
#   'name': 'Esperance',
#   'cod': 200},
#  {'coord': {'lon': 84.6, 'lat': 18.93},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 305,
#    'pressure': 1007.41,
#    'humidity': 64,
#    'temp_min': 305,
#    'temp_max': 305,
#    'sea_level': 1007.41,
#    'grnd_level': 988.38},
#   'wind': {'speed': 3.5, 'deg': 220.772},
#   'clouds': {'all': 0},
#   'dt': 1557202238,
#   'sys': {'message': 0.0041,
#    'country': 'IN',
#    'sunrise': 1557186654,
#    'sunset': 1557233126},
#   'id': 1255816,
#   'name': 'Sompeta',
#   'cod': 200},
#  {'coord': {'lon': 102.47, 'lat': 71.98},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 264.2,
#    'pressure': 1008.94,
#    'humidity': 85,
#    'temp_min': 264.2,
#    'temp_max': 264.2,
#    'sea_level': 1008.94,
#    'grnd_level': 1006.17},
#   'wind': {'speed': 3.08, 'deg': 296.166},
#   'clouds': {'all': 26},
#   'dt': 1557202239,
#   'sys': {'message': 0.0051,
#    'country': 'RU',
#    'sunrise': 1557165851,
#    'sunset': 1557245352},
#   'id': 2022572,
#   'name': 'Khatanga',
#   'cod': 200},
#  {'coord': {'lon': 30.8, 'lat': 59.77},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 278.68,
#    'pressure': 1008,
#    'humidity': 87,
#    'temp_min': 278.15,
#    'temp_max': 279.15},
#   'visibility': 9000,
#   'wind': {'speed': 2, 'deg': 30},
#   'clouds': {'all': 90},
#   'dt': 1557202238,
#   'sys': {'type': 1,
#    'id': 8926,
#    'message': 0.0054,
#    'country': 'RU',
#    'sunrise': 1557193270,
#    'sunset': 1557252333},
#   'id': 513898,
#   'name': 'Otradnoye',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 134.5, 'lat': 33.93},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 289.33,
#    'pressure': 1015,
#    'humidity': 29,
#    'temp_min': 288.15,
#    'temp_max': 290.15},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 360},
#   'clouds': {'all': 20},
#   'dt': 1557202184,
#   'sys': {'type': 1,
#    'id': 8027,
#    'message': 0.0057,
#    'country': 'JP',
#    'sunrise': 1557173276,
#    'sunset': 1557222553},
#   'id': 1865309,
#   'name': 'Katsuura',
#   'cod': 200},
#  {'coord': {'lon': -109.91, 'lat': 22.89},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 296.16,
#    'pressure': 1013,
#    'humidity': 24,
#    'temp_min': 292.59,
#    'temp_max': 299.15},
#   'visibility': 19312,
#   'wind': {'speed': 4.6, 'deg': 120},
#   'clouds': {'all': 5},
#   'dt': 1557201952,
#   'sys': {'type': 1,
#    'id': 7165,
#    'message': 0.0068,
#    'country': 'MX',
#    'sunrise': 1557146617,
#    'sunset': 1557193731},
#   'id': 3985710,
#   'name': 'Cabo San Lucas',
#   'cod': 200},
#  {'coord': {'lon': -7.57, 'lat': 9.51},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 299.7,
#    'pressure': 1010.68,
#    'humidity': 72,
#    'temp_min': 299.7,
#    'temp_max': 299.7,
#    'sea_level': 1010.68,
#    'grnd_level': 960.56},
#   'wind': {'speed': 1.83, 'deg': 196.72},
#   'clouds': {'all': 100},
#   'dt': 1557202240,
#   'sys': {'message': 0.0044,
#    'country': 'CI',
#    'sunrise': 1557209505,
#    'sunset': 1557254515},
#   'id': 2283016,
#   'name': 'Odienne',
#   'cod': 200},
#  {'coord': {'lon': 32.53, 'lat': 34.92},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 291.15,
#    'pressure': 1013,
#    'humidity': 59,
#    'temp_min': 291.15,
#    'temp_max': 291.15},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 310},
#   'clouds': {'all': 20},
#   'dt': 1557199800,
#   'sys': {'type': 1,
#    'id': 6374,
#    'message': 0.0052,
#    'country': 'CY',
#    'sunrise': 1557197622,
#    'sunset': 1557247150},
#   'id': 146639,
#   'name': 'Lasa',
#   'cod': 200},
#  {'coord': {'lon': 123.37, 'lat': 66.77},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 271.7,
#    'pressure': 1001.76,
#    'humidity': 91,
#    'temp_min': 271.7,
#    'temp_max': 271.7,
#    'sea_level': 1001.76,
#    'grnd_level': 989.05},
#   'wind': {'speed': 5.19, 'deg': 139.276},
#   'clouds': {'all': 100},
#   'dt': 1557202240,
#   'sys': {'message': 0.0047,
#    'country': 'RU',
#    'sunrise': 1557167637,
#    'sunset': 1557233534},
#   'id': 2012530,
#   'name': 'Zhigansk',
#   'cod': 200},
#  {'coord': {'lon': 122.95, 'lat': 10.68},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 303.6,
#    'pressure': 1009.18,
#    'humidity': 71,
#    'temp_min': 303.6,
#    'temp_max': 303.6,
#    'sea_level': 1009.18,
#    'grnd_level': 1006.06},
#   'wind': {'speed': 5.58, 'deg': 215.474},
#   'rain': {'3h': 0.688},
#   'clouds': {'all': 100},
#   'dt': 1557202240,
#   'sys': {'message': 0.0047,
#    'country': 'PH',
#    'sunrise': 1557178099,
#    'sunset': 1557223274},
#   'id': 1729564,
#   'name': 'Bacolod',
#   'cod': 200},
#  {'coord': {'lon': 100.24, 'lat': 25.6},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 294.9,
#    'pressure': 1008.03,
#    'humidity': 39,
#    'temp_min': 294.9,
#    'temp_max': 294.9,
#    'sea_level': 1008.03,
#    'grnd_level': 793.02},
#   'wind': {'speed': 3.88, 'deg': 246.435},
#   'clouds': {'all': 16},
#   'dt': 1557202241,
#   'sys': {'message': 0.0047,
#    'country': 'CN',
#    'sunrise': 1557182325,
#    'sunset': 1557229948},
#   'id': 1814093,
#   'name': 'Dali',
#   'cod': 200},
#  {'coord': {'lon': -111.04, 'lat': 45.68},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 278.36,
#    'pressure': 1016,
#    'humidity': 56,
#    'temp_min': 275.37,
#    'temp_max': 281.15},
#   'visibility': 16093,
#   'wind': {'speed': 5.7, 'deg': 40},
#   'clouds': {'all': 1},
#   'dt': 1557202053,
#   'sys': {'type': 1,
#    'id': 3964,
#    'message': 0.0064,
#    'country': 'US',
#    'sunrise': 1557144281,
#    'sunset': 1557196609},
#   'id': 5641727,
#   'name': 'Bozeman',
#   'cod': 200},
#  {'coord': {'lon': 78.75, 'lat': 14.06},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 308.15,
#    'pressure': 1008,
#    'humidity': 47,
#    'temp_min': 308.15,
#    'temp_max': 308.15},
#   'visibility': 6000,
#   'wind': {'speed': 8.7, 'deg': 280},
#   'clouds': {'all': 59},
#   'dt': 1557199800,
#   'sys': {'type': 1,
#    'id': 9210,
#    'message': 0.0051,
#    'country': 'IN',
#    'sunrise': 1557188446,
#    'sunset': 1557234142},
#   'id': 1258291,
#   'name': 'Rayachoti',
#   'cod': 200},
#  {'coord': {'lon': -17.45, 'lat': 14.69},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 295.11,
#    'pressure': 1011,
#    'humidity': 69,
#    'temp_min': 294.15,
#    'temp_max': 296.15},
#   'visibility': 9000,
#   'wind': {'speed': 9.8, 'deg': 20},
#   'clouds': {'all': 64},
#   'dt': 1557199800,
#   'sys': {'type': 1,
#    'id': 2410,
#    'message': 0.0049,
#    'country': 'SN',
#    'sunrise': 1557211479,
#    'sunset': 1557257283},
#   'id': 2253354,
#   'name': 'Dakar',
#   'cod': 200},
#  {'coord': {'lon': -90.35, 'lat': -0.74},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 298.15,
#    'pressure': 1011,
#    'humidity': 95,
#    'temp_min': 298.15,
#    'temp_max': 298.15},
#   'wind': {'speed': 2.79, 'deg': 166.238},
#   'clouds': {'all': 38},
#   'dt': 1557201632,
#   'sys': {'type': 3,
#    'id': 2005652,
#    'message': 0.0054,
# ...
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 340},
#   'clouds': {'all': 40},
#   'dt': 1557198000,
#   'sys': {'type': 1,
#    'id': 9560,
#    'message': 0.0043,
#    'country': 'AU',
#    'sunrise': 1557177756,
#    'sunset': 1557215059},
#   'id': 2156643,
#   'name': 'Mount Gambier',
#   'cod': 200},
#  {'coord': {'lon': -112.04, 'lat': 43.49},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 287.89,
#    'pressure': 1011,
#    'humidity': 45,
#    'temp_min': 285.37,
#    'temp_max': 289.15},
#   'visibility': 16093,
#   'wind': {'speed': 2.6, 'deg': 260},
#   'clouds': {'all': 75},
#   'dt': 1557202236,
#   'sys': {'type': 1,
#    'id': 4491,
#    'message': 0.0053,
#    'country': 'US',
#    'sunrise': 1557144857,
#    'sunset': 1557196513},
#   'id': 5596475,
#   'name': 'Idaho Falls',
#   'cod': 200},
#  {'coord': {'lon': -5.74, 'lat': 41.51},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 282.21,
#    'pressure': 1018,
#    'humidity': 93,
#    'temp_min': 280.93,
#    'temp_max': 284.82},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 230},
#   'clouds': {'all': 55},
#   'dt': 1557202302,
#   'sys': {'type': 1,
#    'id': 6430,
#    'message': 0.0048,
#    'country': 'ES',
#    'sunrise': 1557205976,
#    'sunset': 1557257166},
#   'id': 3104342,
#   'name': 'Zamora',
#   'cod': 200},
#  {'coord': {'lon': 27.38, 'lat': 45.68},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 282.15,
#    'pressure': 1004,
#    'humidity': 87,
#    'temp_min': 282.15,
#    'temp_max': 282.15},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 30},
#   'clouds': {'all': 90},
#   'dt': 1557201600,
#   'sys': {'type': 1,
#    'id': 9687,
#    'message': 0.0045,
#    'country': 'RO',
#    'sunrise': 1557197410,
#    'sunset': 1557249835},
#   'id': 665754,
#   'name': 'Suraia',
#   'cod': 200},
#  {'coord': {'lon': 51.53, 'lat': 25.29},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 302.29,
#    'pressure': 1008,
#    'humidity': 22,
#    'temp_min': 300.15,
#    'temp_max': 305.15},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 300},
#   'clouds': {'all': 0},
#   'dt': 1557199800,
#   'sys': {'type': 1,
#    'id': 7614,
#    'message': 0.0049,
#    'country': 'QA',
#    'sunrise': 1557194038,
#    'sunset': 1557241615},
#   'id': 290030,
#   'name': 'Doha',
#   'cod': 200},
#  {'coord': {'lon': 175.7, 'lat': -36.83},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 292.59,
#    'pressure': 1025,
#    'humidity': 76,
#    'temp_min': 292.59,
#    'temp_max': 292.59},
#   'wind': {'speed': 1.34, 'deg': 84, 'gust': 4.02},
#   'rain': {'3h': 0.062},
#   'clouds': {'all': 67},
#   'dt': 1557202210,
#   'sys': {'type': 3,
#    'id': 2002961,
#    'message': 0.0047,
#    'country': 'NZ',
#    'sunrise': 1557169257,
#    'sunset': 1557206796},
#   'id': 2179103,
#   'name': 'Whitianga',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -57.68, 'lat': -36.31},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 281,
#    'pressure': 1023.54,
#    'humidity': 80,
#    'temp_min': 281,
#    'temp_max': 281,
#    'sea_level': 1023.54,
#    'grnd_level': 1022.85},
#   'wind': {'speed': 2.57, 'deg': 113.155},
#   'clouds': {'all': 0},
#   'dt': 1557202208,
#   'sys': {'message': 0.0044,
#    'country': 'AR',
#    'sunrise': 1557225244,
#    'sunset': 1557262827},
#   'id': 3435038,
#   'name': 'Dolores',
#   'cod': 200},
#  {'coord': {'lon': 15.22, 'lat': 46.61},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 273.82,
#    'pressure': 1018,
#    'humidity': 80,
#    'temp_min': 272.04,
#    'temp_max': 275.37},
#   'visibility': 10000,
#   'wind': {'speed': 0.5, 'deg': 280},
#   'clouds': {'all': 1},
#   'dt': 1557202329,
#   'sys': {'type': 1,
#    'id': 6825,
#    'message': 0.0053,
#    'country': 'SI',
#    'sunrise': 1557200172,
#    'sunset': 1557252910},
#   'id': 3192121,
#   'name': 'Radlje ob Dravi',
#   'cod': 200},
#  {'coord': {'lon': 57.66, 'lat': -20.01},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 298.37,
#    'pressure': 1018,
#    'humidity': 83,
#    'temp_min': 298.15,
#    'temp_max': 298.71},
#   'visibility': 10000,
#   'wind': {'speed': 5.39, 'deg': 104.732},
#   'clouds': {'all': 75},
#   'dt': 1557202137,
#   'sys': {'type': 1,
#    'id': 2061,
#    'message': 0.0047,
#    'country': 'MU',
#    'sunrise': 1557196038,
#    'sunset': 1557236673},
#   'id': 934479,
#   'name': 'Grand Gaube',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 97.97, 'lat': 4.47},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 302.9,
#    'pressure': 1011.41,
#    'humidity': 56,
#    'temp_min': 302.9,
#    'temp_max': 302.9,
#    'sea_level': 1011.41,
#    'grnd_level': 950.32},
#   'wind': {'speed': 0.86, 'deg': 62.424},
#   'clouds': {'all': 99},
#   'dt': 1557202198,
#   'sys': {'message': 0.0048,
#    'country': 'ID',
#    'sunrise': 1557184551,
#    'sunset': 1557228812},
#   'id': 1214724,
#   'name': 'Langsa',
#   'cod': 200},
#  {'coord': {'lon': -78.7, 'lat': 46.32},
#   'weather': [{'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50n'}],
#   'base': 'stations',
#   'main': {'temp': 277.1,
#    'pressure': 1017,
#    'humidity': 100,
#    'temp_min': 277.04,
#    'temp_max': 277.15},
#   'visibility': 201,
#   'wind': {'speed': 4.6, 'deg': 310},
#   'clouds': {'all': 90},
#   'dt': 1557201916,
#   'sys': {'type': 1,
#    'id': 988,
#    'message': 0.0046,
#    'country': 'CA',
#    'sunrise': 1557222739,
#    'sunset': 1557275422},
#   'id': 6067959,
#   'name': 'Mattawa',
#   'cod': 200},
#  {'coord': {'lon': -56.83, 'lat': -26.98},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 294.8,
#    'pressure': 1015.16,
#    'humidity': 97,
#    'temp_min': 294.8,
#    'temp_max': 294.8,
#    'sea_level': 1015.16,
#    'grnd_level': 1003.25},
#   'wind': {'speed': 1.05, 'deg': 84.583},
#   'clouds': {'all': 0},
#   'dt': 1557202343,
#   'sys': {'message': 0.0057,
#    'country': 'PY',
#    'sunrise': 1557224115,
#    'sunset': 1557263549},
#   'id': 3437029,
#   'name': 'San Patricio',
#   'cod': 200},
#  {'coord': {'lon': -16.33, 'lat': 33.08},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 290,
#    'pressure': 1021,
#    'humidity': 82,
#    'temp_min': 289.15,
#    'temp_max': 291.15},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 170},
#   'clouds': {'all': 40},
#   'dt': 1557199800,
#   'sys': {'type': 1,
#    'id': 6902,
#    'message': 0.0048,
#    'country': 'PT',
#    'sunrise': 1557209545,
#    'sunset': 1557258679},
#   'id': 2270385,
#   'name': 'Camacha',
#   'cod': 200},
#  {'coord': {'lon': 122.68, 'lat': 13.32},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 305,
#    'pressure': 1008.09,
#    'humidity': 61,
#    'temp_min': 305,
#    'temp_max': 305,
#    'sea_level': 1008.09,
#    'grnd_level': 998.21},
#   'wind': {'speed': 2.76, 'deg': 235.556},
#   'clouds': {'all': 100},
#   'dt': 1557202344,
#   'sys': {'message': 0.0041,
#    'country': 'PH',
#    'sunrise': 1557177963,
#    'sunset': 1557223540},
#   'id': 1690438,
#   'name': 'San Andres',
#   'cod': 200},
#  {'coord': {'lon': 48.53, 'lat': 5.35},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 301.1,
#    'pressure': 1011.35,
#    'humidity': 76,
#    'temp_min': 301.1,
#    'temp_max': 301.1,
#    'sea_level': 1011.35,
#    'grnd_level': 994.72},
#   'wind': {'speed': 4.42, 'deg': 163.777},
#   'rain': {'3h': 0.625},
#   'clouds': {'all': 41},
#   'dt': 1557202344,
#   'sys': {'message': 0.0045,
#    'country': 'SO',
#    'sunrise': 1557196351,
#    'sunset': 1557240742},
#   'id': 57000,
#   'name': 'Hobyo',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 40.99, 'lat': 41.19},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 294.15,
#    'pressure': 1007,
#    'humidity': 49,
#    'temp_min': 294.15,
#    'temp_max': 294.15},
#   'visibility': 10000,
#   'wind': {'speed': 9.3, 'deg': 130},
#   'clouds': {'all': 0},
#   'dt': 1557199800,
#   'sys': {'type': 1,
#    'id': 8858,
#    'message': 0.0046,
#    'country': 'TR',
#    'sunrise': 1557194814,
#    'sunset': 1557245898},
#   'id': 751949,
#   'name': 'Ardesen',
#   'cod': 200},
#  {'coord': {'lon': 129.44, 'lat': 50.11},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 287.3,
#    'pressure': 1003.15,
#    'humidity': 29,
#    'temp_min': 287.3,
#    'temp_max': 287.3,
#    'sea_level': 1003.15,
#    'grnd_level': 975.66},
#   'wind': {'speed': 5.54, 'deg': 351.325},
#   'clouds': {'all': 37},
#   'dt': 1557202345,
#   'sys': {'message': 0.0064,
#    'country': 'RU',
#    'sunrise': 1557172153,
#    'sunset': 1557226105},
#   'id': 2012626,
#   'name': 'Zavitinsk',
#   'cod': 200},
#  {'coord': {'lon': 14.57, 'lat': 32.47},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 288.8,
#    'pressure': 1020.71,
#    'humidity': 60,
#    'temp_min': 288.8,
#    'temp_max': 288.8,
#    'sea_level': 1020.71,
#    'grnd_level': 1017.52},
#   'wind': {'speed': 0.25, 'deg': 144.382},
#   'clouds': {'all': 0},
#   'dt': 1557202148,
#   'sys': {'message': 0.0041,
#    'country': 'LY',
#    'sunrise': 1557202199,
#    'sunset': 1557251194},
#   'id': 2208485,
#   'name': 'Zlitan',
#   'cod': 200},
#  {'coord': {'lon': -110.23, 'lat': 23.45},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 296.53,
#    'pressure': 1013,
#    'humidity': 24,
#    'temp_min': 292.59,
#    'temp_max': 299.15},
#   'visibility': 19312,
#   'wind': {'speed': 4.6, 'deg': 120},
#   'clouds': {'all': 5},
#   'dt': 1557202254,
#   'sys': {'type': 1,
#    'id': 7165,
#    'message': 0.0073,
#    'country': 'MX',
#    'sunrise': 1557146645,
#    'sunset': 1557193856},
#   'id': 3981432,
#   'name': 'Todos Santos',
#   'cod': 200},
#  {'coord': {'lon': 48.57, 'lat': 50.14},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 287.6,
#    'pressure': 1010.7,
#    'humidity': 89,
#    'temp_min': 287.6,
#    'temp_max': 287.6,
#    'sea_level': 1010.7,
#    'grnd_level': 1006.29},
#   'wind': {'speed': 4.55, 'deg': 234.979},
#   'clouds': {'all': 9},
#   'dt': 1557202346,
#   'sys': {'message': 0.0057,
#    'country': 'RU',
#    'sunrise': 1557191533,
#    'sunset': 1557245540},
#   'id': 583345,
#   'name': 'Aleksandrov Gay',
#   'cod': 200},
#  {'coord': {'lon': 27.3, 'lat': 48.17},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 278.15,
#    'pressure': 1005,
#    'humidity': 89,
#    'temp_min': 278.15,
#    'temp_max': 278.15},
#   'wind': {'speed': 0.89, 'deg': 225, 'gust': 0.89},
#   'rain': {'3h': 1.125},
#   'clouds': {'all': 100},
#   'dt': 1557202231,
#   'sys': {'type': 3,
#    'id': 2019073,
#    'message': 0.0057,
#    'country': 'MD',
#    'sunrise': 1557197004,
#    'sunset': 1557250279},
#   'id': 617076,
#   'name': 'Edinet',
#   'cod': 200},
#  {'coord': {'lon': 114.88, 'lat': 40.77},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 286.6,
#    'pressure': 1017.8,
#    'humidity': 14,
#    'temp_min': 286.6,
#    'temp_max': 286.6,
#    'sea_level': 1017.8,
#    'grnd_level': 856.83},
#   'wind': {'speed': 1.81, 'deg': 289.347},
#   'clouds': {'all': 58},
#   'dt': 1557202346,
#   'sys': {'message': 0.0038,
#    'country': 'CN',
#    'sunrise': 1557177152,
#    'sunset': 1557228094},
#   'id': 2033196,
#   'name': 'Zhangjiakou',
#   'cod': 200},
#  {'coord': {'lon': -60.63, 'lat': -9.17},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 297.7,
#    'pressure': 1013.04,
#    'humidity': 81,
#    'temp_min': 297.7,
#    'temp_max': 297.7,
#    'sea_level': 1013.04,
#    'grnd_level': 993.95},
#   'wind': {'speed': 0.21, 'deg': 106.648},
#   'clouds': {'all': 78},
#   'dt': 1557202346,
#   'sys': {'message': 0.0045,
#    'country': 'BR',
#    'sunrise': 1557223603,
#    'sunset': 1557265885},
#   'id': 3665202,
#   'name': 'Aripuana',
#   'cod': 200},
#  {'coord': {'lon': -66.38, 'lat': 50.2},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 279.46,
#    'pressure': 1015,
#    'humidity': 52,
#    'temp_min': 279.15,
#    'temp_max': 279.82},
#   'visibility': 24140,
#   'wind': {'speed': 5.7, 'deg': 80, 'gust': 9.3},
#   'clouds': {'all': 75},
#   'dt': 1557201692,
#   'sys': {'type': 1,
#    'id': 1013,
#    'message': 0.0049,
#    'country': 'CA',
#    'sunrise': 1557219078,
#    'sunset': 1557273170},
#   'id': 6144312,
#   'name': 'Sept-Iles',
#   'cod': 200},
#  {'coord': {'lon': 24.73, 'lat': 2.79},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 294.7,
#    'pressure': 1010.62,
#    'humidity': 98,
#    'temp_min': 294.7,
#    'temp_max': 294.7,
#    'sea_level': 1010.62,
#    'grnd_level': 959.57},
#   'wind': {'speed': 0.37, 'deg': 297.402},
#   'clouds': {'all': 100},
#   'dt': 1557202347,
#   'sys': {'message': 0.0046,
#    'country': 'CD',
#    'sunrise': 1557202249,
#    'sunset': 1557246268},
#   'id': 217570,
#   'name': 'Buta',
#   'cod': 200},
#  {'coord': {'lon': -17.92, 'lat': 28.66},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 292.15,
#    'pressure': 1021,
#    'humidity': 63,
#    'temp_min': 292.15,
#    'temp_max': 292.15},
#   'visibility': 10000,
#   'wind': {'speed': 5.7, 'deg': 360},
#   'clouds': {'all': 90},
#   'dt': 1557199800,
#   'sys': {'type': 1,
#    'id': 2377,
#    'message': 0.005,
#    'country': 'ES',
#    'sunrise': 1557210381,
#    'sunset': 1557258607},
#   'id': 2514651,
#   'name': 'Los Llanos de Aridane',
#   'cod': 200},
#  {'coord': {'lon': -84.82, 'lat': 39.26},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 288.61,
#    'pressure': 1019,
#    'humidity': 82,
#    'temp_min': 286.15,
#    'temp_max': 290.93},
#   'visibility': 16093,
#   'wind': {'speed': 2.36, 'deg': 219.933},
#   'clouds': {'all': 1},
#   'dt': 1557202331,
#   'sys': {'type': 1,
#    'id': 4476,
#    'message': 0.0093,
#    'country': 'US',
#    'sunrise': 1557225242,
#    'sunset': 1557275857},
#   'id': 4513805,
#   'name': 'Harrison',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 37.1, 'lat': 9.57},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 288.3,
#    'pressure': 1014.99,
#    'humidity': 75,
#    'temp_min': 288.3,
#    'temp_max': 288.3,
#    'sea_level': 1014.99,
#    'grnd_level': 784.54},
#   'wind': {'speed': 1.74, 'deg': 104.675},
#   'rain': {'3h': 3.312},
#   'clouds': {'all': 91},
#   'dt': 1557202347,
#   'sys': {'message': 0.0042,
#    'country': 'ET',
#    'sunrise': 1557198782,
#    'sunset': 1557243797},
#   'id': 328709,
#   'name': 'Shambu',
#   'cod': 200}]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
from pprint import pprint
#length of the json response
City = []
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []

#construct and append all json data in the loop and create a dataframe 
for x in range(len(response_json)):
    try:
        city = response_json[x]['name']
    #City.append(city)
    
   
#     clouds = response_json[x]['clouds']['all']
#     Cloudiness.append(clouds)
    
#     country = response_json[x]['sys']['country']
#     Country.append(country)
    
#     date = response_json[x]['dt']
#     Date.append(date)
    
#     humidity = response_json[x]['main']['humidity']
#     Humidity.append(humidity)
    
#     lon = response_json[x]['coord']['lon']
#     Lng.append(lon)
    
    
#     lat = response_json[x]['coord']['lat']
#     Lat.append(lat)
    
    
    temp_max = response_json[x]['main']['temp_max']
    Max_Temp.append(temp_max)
    
    
    wind_speed = response_json[x]['wind']['speed']
    Wind_Speed.append(wind_speed)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-17d91d31aa6c> in <module>
#      14 for x in range(len(response_json)):
#      15
# ---> 16     city = response_json[x]['name']
#      17     #City.append(city)
#      18
#
# KeyError: 'name'

# %%
#Create dataframe
weather_df = pd.DataFrame()
weather_df['City'] = City
weather_df['Country'] = Country
weather_df['Sunrise'] = Sunrise
weather_df['Humidity'] = Humidity
weather_df['Lat'] = Lat
weather_df['Lng'] = Lng
weather_df['Max_Temp'] = Max_Temp
weather_df['Wind_Speed'] = Wind_Speed

weather_df
# Out:
#      City Country     Sunrise  Humidity    Lat    Lng  Max_Temp  Wind_Speed
# 0  Zaysan      KZ  1557183325        39  47.47  84.87     287.4        1.32

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
